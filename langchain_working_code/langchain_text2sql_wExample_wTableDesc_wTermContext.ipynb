# %% [markdown]
# # Text-to-SQL Chain with Query Examples, Table Descriptions, and Term Context
# ### DB: AWS S3
# ### SQL: AWS Athena
# ### Chat History Storage: AWS DynamoDB
# ### Vector Store: FAISS
# ### LLM: GPT4

# %% [markdown]
# ## Chain:

# %% [markdown]
# ![Screenshot 2024-07-30 at 11.40.03 PM.png](attachment:f74a23a9-1bec-44cf-a889-033eb8ed1677.png)

# %%
import getpass
import os
import json
import boto3

from typing import List

import pandas as pd
import matplotlib.pyplot as plt

import jq

import openai
import anthropic
from langchain.globals import set_debug
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain.output_parsers.json import SimpleJsonOutputParser
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers.openai_tools import PydanticToolsParser
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate, MessagesPlaceholder
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_community.document_loaders import JSONLoader
from langchain_community.document_loaders.merge import MergedDataLoader
from langchain_community.vectorstores import FAISS
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain_community.chat_message_histories import (
    DynamoDBChatMessageHistory,
)
from langchain.agents.format_scratchpad.openai_tools import (
    format_to_openai_tool_messages,
)
from langchain.agents.output_parsers.openai_tools import OpenAIToolsAgentOutputParser
from langchain.agents import tool
from langchain.agents import AgentExecutor

from sqlalchemy import create_engine
from urllib.parse import quote_plus

#set environmental variable for OpenAI API key
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %%
#os.environ["LANGCHAIN_TRACING_V2"]="true"
#os.environ["LANGCHAIN_PROJECT"]="langchainllmproject"
#os.environ["LANGCHAIN_ENDPOINT"]= "https://api.smith.langchain.com" 
#os.environ["LANGCHAIN_API_KEY"]="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"

# %% [markdown]
# #### set up AWS DynamoDB for Chat History

# %%
def load_db():
    #database info
    AWS_REGION = "us-east-1"
    SCHEMA_NAME = "wnba_db"
    S3_STAGING_DIR = "s3://wnbadata/"
    
    connect_str = "awsathena+rest://athena.{region_name}.amazonaws.com:443/{schema_name}?s3_staging_dir={s3_staging_dir}"
    
    #connect to AWS athena
    engine = create_engine(connect_str.format(
            region_name=AWS_REGION,
            schema_name=SCHEMA_NAME,
            s3_staging_dir=quote_plus(S3_STAGING_DIR)
    ))
    
    #create SQL db object
    return SQLDatabase(engine)

# %%
#create a Pydantic Base Model
class Table(BaseModel):
    """Table in SQL database."""
    name: str = Field(description = "Name of table in SQL database.")

#create table chain
class TableChain:
    def __init__(self, model_name):
        self.model_name = model_name
        self.table_chain = self.create_table_chain()

    def get_table_details(self):
        file_paths = [
            "src/wnba_nba_pbp_data_dict.json",
            "src/wnba_player_box.json",
            "src/wnba_player_info.json",
            "src/wnba_schedule.json",
            "src/wnba_teambox.json"
        ]
        
        table_details = ""
    
        for file_path in file_paths:
            
            #load table names and descriptions from json
            f = open(file_path)
            table_dict = json.load(f)
            
            #retrieve table names and descriptions and compile into string
            table_details = table_details + "Table Name:" + table_dict['table_name'] + "\n" \
            + "Table Description:" + table_dict['table_description']
    
            for col in table_dict['values']:
                table_details = table_details + "\n" + "Column Name:" + col['column_name'] + "\n" \
                + "Column Description:" + col['column_description'] + "\n" \
                + "COlumn Type:" + col['column_type']
            
            table_details = table_details + "\n\n"
        
        return table_details

    def create_table_chain(self):
        
        table_details = self.get_table_details()
        
        #create table chain prompt
        table_prompt_system = f"""Refer the Above Context and Return the names of SQL Tables that MIGHT be relevant to the above context\n\n 
        The tables are:
        
        {table_details}
         """
        
        table_details_prompt = ChatPromptTemplate.from_messages(
            [
                ("system", table_prompt_system),
                ("human", "{input}"),
            ]
        )
        
        #set up LLM
        if "claude" in self.model_name:
            table_chain_llm = ChatAnthropic(model = self.model_name, temperature = 0)
        else:
            table_chain_llm = ChatOpenAI(model_name = self.model_name, temperature = 0)
        table_chain_llm_wtools = table_chain_llm.bind_tools([Table])
        output_parser = PydanticToolsParser(tools=[Table])

        #create table chain
        table_chain = table_details_prompt | table_chain_llm_wtools | output_parser

        return table_chain

    def invoke(self, query):
        return self.table_chain.invoke(query)

# %%
#create visulization chain
class VisualizationChain:
    def __init__(self, model_name):
        self.model_name = model_name
        self.visualization_chain = self.create_visualization_chain()

    def create_visualization_chain(self):
        json_parser = SimpleJsonOutputParser()
        #set up LLM
        vis_llm = ChatOpenAI(model_name = self.model_name, temperature = 0)
        vis_chain = vis_llm | json_parser
        return vis_chain

    def invoke(self, query):
        vis_prompt = (
            """
            You are a data visualization expert.
            Determine which of table, bar chart, line chart, or no chart required is the most suitable for visualizating the following context.
            
            If it requires drawing a table, reply as follows:
            {"table": {"columns": ["column1", "column2", ...], "data": [[value1, value2, ...], [value1, value2, ...], ...]}}
            
            If the query requires creating a bar chart, reply as follows:
            {"bar": {"columns": ["A", "B", "C", ...], "data": [25, 24, 10, ...]}}
            
            If the query requires creating a line chart, reply as follows:
            {"line": {"columns": ["A", "B", "C", ...], "data": [25, 24, 10, ...]}}
            
            There can only be two types of chart, "bar" and "line".
            
            If you think neither is suitable or itt requires neither, reply as follows:
            {"answer": "I do not know."}
            
            Return all output as a string.
            
            All strings in "columns" list and data list, should be in double quotes,
            
            For example: {"columns": ["title", "ratings_count"], "data": [["Gilead", 361], ["Spider's Web", 5164]]}
            
            Lets think step by step.
            
            Below is the context.
            Context:
            """
            + str(query)
        )
        
        response = self.visualization_chain.invoke(vis_prompt)
        self.plot(response)
        
    def plot(self, response_dict):
        # Check if the response is an answer.
        if "answer" in response_dict:
            return
        try:
            # Check if the response is a bar chart.
            if "bar" in response_dict:
                data = response_dict["bar"]
                df = pd.DataFrame.from_dict(data)
                plt.bar(df["columns"].values, df["data"].values)
                plt.xticks(rotation = 315)
                plt.show()
            # Check if the response is a line chart.
            elif "line" in response_dict:
                data = response_dict["line"]
                df = pd.DataFrame.from_dict(data)
                plt.plot(df["columns"].values, df["data"].values)
                plt.xticks(rotation = 315)
                plt.show()
        
            # Check if the response is a table.
            elif "table" in response_dict:
                data = response_dict["table"]
                df = pd.DataFrame(data["data"], columns = data["columns"])
                plt.table(cellText = df.values, colLabels = df.columns, loc='center')
                plt.axis("off")
                plt.show()
        except ValueError as e:
            return

# %%
#create term context chain
class TermContextChain:
    def __init__(self, model_name):
        self.model_name = model_name
        self.retriever = self.create_vector_retriever()
        self.term_context_chain = self.create_term_context_chain()

    def metadata_func(self, record, metadata):
        # Extracting column details using list comprehension
        term_name = [key for key in record]
        term_desc = [value for key, value in record.items()]
    
        metadata.update({
            "Term_name": str(term_name),
            "Term_Description": str(term_desc)
        })
        
        return metadata

    def load_doc(self):
        json_loader = JSONLoader(
            file_path = "src/basketball_metrics.json",
            jq_schema = '.',
            text_content = False,
            metadata_func = self.metadata_func
        )
        
        return json_loader.load()

    def create_vector_retriever(self):
        vector_db = FAISS.from_documents(self.load_doc(), OpenAIEmbeddings())
        #vector_db = Chroma.from_documents(self.load_doc(), OpenAIEmbeddings())
        
        return vector_db.as_retriever()

    def create_term_context_chain(self):
        term_contex_llm = ChatOpenAI(model_name = self.model_name, temperature = 0)
    
        term_context_prompt = ChatPromptTemplate.from_template(
            """
            Answer the question based only on the following context:
            {context}
            Search for the term name and descriptions in the context. Include only relevant term which can be used by the downstream Text-to-SQL Agent to create SQL Queries for generating answer.
            Search for any information performing the following tasks:
            1. Term Names
            2. Term Descriptions
            Finally, only return term names and descriptions (if availabe).
        
            Question: {question}
            """
        )
                    
        context_retriever_chain = (
            {"context": self.retriever, "question": RunnablePassthrough()}
            | term_context_prompt
            | term_contex_llm
            | StrOutputParser()
        )

        return context_retriever_chain

    def invoke(self, query):
        return self.term_context_chain.invoke(query)

# %%
#create text2sql chain
class QAEngine:
    def __init__(self, model_name, db, session_id, user_id):
        self.model_name = model_name
        self.db = db
        #self.chat_history = None
        #self.load_chat_history(session_id, user_id)
        self.query_examples = self.load_query_examples()
        self.table_chain = TableChain(model_name)
        #self.visualization_chain = VisualizationChain(model_name)
        self.term_context_chain = TermContextChain(model_name)
        self.text_sql_agent, self.sql_tools = self.create_text_sql_agent()

    def update_db(self, db):
        self.db = db

    def load_chat_history(self, session_id, user_id):
        #set up dynamodb
        dynamodb = boto3.resource("dynamodb")
        
        sessionid = f"session_id::{session_id}"
        userid = f"{user_id:04}"
        
        #create composite key (session id & user id) for accessing databases
        composite_key = {
            "SessionId": sessionid,
            "UserID": userid,
        }
        
        #query DynamoDB for chat history using the composite key
        chat_history = DynamoDBChatMessageHistory(
            table_name = "Chat_Table",
            session_id = "0",
            key = composite_key,
            history_size = 6,
        )

        self.chat_history = chat_history

    def load_query_examples(self):
        #load query examples from json
        f = open("src/query_example.json")
        query_examples_json = json.load(f)
        
        return query_examples_json["query_examples"]

    def create_text_sql_agent(self):
        #set up LLM
        if "claude" in self.model_name:
            llm = ChatAnthropic(model = self.model_name, temperature = 0)
        else:
            llm = ChatOpenAI(model_name = self.model_name, temperature= 0)
        #utilize langchain agent toolkit: SQL toolkit
        toolkit = SQLDatabaseToolkit(db = self.db, llm = llm)
        tools = toolkit.get_tools()
        llm_with_tools = llm.bind_tools(tools)
        
        #create few shot prompt with query examples
        example_prompt = ChatPromptTemplate.from_messages(["User input: {input}\nSQL query: {query}"])
        few_shot_prompt = FewShotChatMessagePromptTemplate(
            examples = self.query_examples,
            example_prompt = example_prompt,
        )
        
        #create prompt for agent
        prompt = ChatPromptTemplate.from_messages([
            (
                "system",
                """
                You are an agent designed to interact with a SQL database and a WNBA expert to answer questions about the WNBA.
                Given an input question, create a syntactically correct SQLite query to run, then look at the results of the query and return the answer.
                If applicable, return the statistical numbers as well.
                You should also leverage your pre-existing knowledge of WNBA rules, statistics, teams, players, and history to understand and interpret user questions and your answer accurately.
                Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most 5 results.
                You can order the results by a relevant column to return the most interesting examples in the database.
                Never query for all the columns from a specific table, only ask for the relevant columns given the question.
                You have access to tools for interacting with the database.
                Base your final answer on the information returned by these tools, combined with your existing knowledge of the WNBA.
                You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.
        
                When referring to a specific game, DO NOT just provide the game ID. You MUST also provide the two teams involved in the game.
                
                DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.
        
                DO NOT give me the SQL query.
                
                You MUST always execute the query and use the result to contruct the final answer.
                
                To start you should ALWAYS look at the tables in the database to see what you can query.
                Do NOT skip this step.
                Then you should query the schema of the most relevant tables.
                Here is the relevant table info, but feel free to use other tables you deem necessary: {table_names_to_use}.
                Here is the relevant terms and descriptions: {term_context}.
                """,
            ),
            few_shot_prompt,
            #MessagesPlaceholder(variable_name = "chat_history"),
            ("user", "{input}"),
            #message placeholder for storing intermediate steps
            MessagesPlaceholder(variable_name = "agent_scratchpad"),
        ])

        #create agent
        agent = (
            {
                "input": lambda x: x["input"],
                "agent_scratchpad": lambda x: format_to_openai_tool_messages(
                    x["intermediate_steps"]
                ),
                #"chat_history": lambda x: x["chat_history"],
                "table_names_to_use": lambda x: x["table_names_to_use"],
                "term_context": lambda x: x["term_context"]
            }
            | prompt
            | llm_with_tools
            | OpenAIToolsAgentOutputParser()
        )
        
        return agent, tools

    def invoke(self, query):
        response = None
        max_iteration = 10
        error_count = 0
        count = 0
        agent_executor = AgentExecutor(agent = self.text_sql_agent, tools = self.sql_tools, verbose = False, return_intermediate_steps = True, max_iterations = max_iteration)
        while response is None and count <= 5:
            try:
                response = agent_executor.invoke({
                    "input": query,
                    #"chat_history": self.chat_history.messages,
                    #passing result of table chain to text2sql agent
                    "table_names_to_use": self.table_chain.invoke(query),
                    "term_context": self.term_context_chain.invoke(query)
                })
            except (openai.BadRequestError, openai.APIError, anthropic.APIStatusError) as e:
                if error_count == 0:
                    max_iteration = 5
                elif error_count == 1:
                    max_iteration = 1
                agent_executor = AgentExecutor(agent = self.text_sql_agent, tools = self.sql_tools, verbose = False, return_intermediate_steps = True, max_iterations = max_iteration)
                error_count += 1
                count += 1
            except Exception as e:
                if response is not None and ('SQL query' in response['output'] or 'Agent stopped' in response['output']):
                    response = None
                    count += 1 
            else:
                if 'SQL query' in response['output'] or 'Agent stopped' in response['output']:
                    response = None
                    count += 1
                    
        if response is not None:
            #self.chat_history.add_user_message(query)
            #self.chat_history.add_ai_message(response["output"])
            #self.visualization_chain.invoke(response["output"])
            return response['output']
        else:
            #self.chat_history.add_user_message(query)
            #self.chat_history.add_ai_message("no response")
            return "no response"

# %%
awsdb = load_db()
gpt4T_text2sql = QAEngine("gpt-4-turbo", awsdb, 205, 1)
# Out:
# /var/folders/1c/ybx_8cds1ybgdg3z19ptmmk00000gn/T/ipykernel_97557/3112801148.py:10: SADeprecationWarning: The dbapi() classmethod on dialect classes has been renamed to import_dbapi().  Implement an import_dbapi() classmethod directly on class <class 'pyathena.sqlalchemy.rest.AthenaRestDialect'> to remove this warning; the old .dbapi() classmethod may be maintained for backwards compatibility.
#   engine = create_engine(connect_str.format(

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 1000)

test_set = pd.read_csv('test_set.csv')
questions = test_set['question']
ground_truths = test_set['answer']

def run_test(model, model_type):
    answers = []

    for query in questions:
        response = model.invoke(query)
        if model_type == "text2sql":
            answers.append(response)
        else:
            answers.append(response.content)
        
    # To dict
    data = {
        "question": questions,
        "answer": answers,
        "ground_truths": ground_truths
    }
    
    dataset = pd.DataFrame.from_dict(data)
    return dataset

# %%
gpt4T_text2sql_result = run_test(gpt4T_text2sql, "text2sql")
gpt4T_text2sql_result

# %%
gpt4T_text2sql_result
# Out:
#                                                                                                                                                                                                       question  \
# 0                                                                                                                                  Which player scored the most points in a single game between 2018 and 2024?
# 1                                                                                                                                       Which team had the highest average points per game in the 2021 season?
# 2                                                                                                                                                     How many games ended in overtime during the 2023 season?
# 3                                                                                                              Which player had the highest free throw percentage in the 2020 season (min. 25 FT’s attempted)?
# 4                                                                                                                                        What was the win-loss record of the Seattle Storm in the 2022 season?
# 5                                                                                                                      Which team had the longest winning streak in the 2019 season (inclusive of postseason)?
# 6                                                                                                How many triple-doubles were recorded in the WNBA between 2018 and 2024, and who had the most triple-doubles?
# 7                                                                                                                                     Which team had the best defense in the 2024 season (by opponent points)?
# 8                                                                                                                            Identify the game with the highest combined score (both teams) from 2018 to 2024.
# 9                                                                                                                                                     Which player played the most minutes in the 2021 season?
# 10                                                                                                                                                What is the average attendance for games in the 2020 season?
# 11                                                                                                                     Which player had the highest number of assists in a single game during the 2019 season?
# 12                                                                                                                           How many times did the Chicago Sky make it to the playoffs between 2018 and 2024?
# 13                                                                                                                           What was the average margin of victory for the Las Vegas Aces in the 2022 season?
# 14                                                                                                                                                        Which player had the most steals in the 2023 season?
# 15                                                                                                                                 Identify the top 5 games with the highest attendance between 2018 and 2024.
# 16                                                                                                              What is the average number of three-point shots made per game by each team in the 2023 season?
# 17                                                                                                                                      Which games had the most technical fouls called between 2018 and 2024?
# 18                                                                                                                                                           Who were the top 3 rebounders in the 2021 season?
# 19                                                                                                                                  What was the total number of blocks by Brittney Griner in the 2023 season?
# 20                                                                                                              How did the average points per game of the top 3 scorers change each season from 2018 to 2024?
# 21                                                                                                                                 Which team had the highest average home game attendance in the 2021 season?
# 22                                                                                                     What was the average plus-minus of players who played more than 30 minutes per game in the 2022 season?
# 23                                                                                                         Which player had the highest scoring average in games where their team lost during the 2020 season?
# 24                                                                                      Compare the shooting percentages of three-point shots versus two-point shots for the top 5 scorers in the 2023 season.
# 25                                                                                                         Which player had the highest average assists in the last 3 minutes of games during the 2021 season?
# 26                                                                                  How did the performance of rookies compare to veterans in the 2019 season in terms of average points and assists per game?
# 27                                                                                                                            Identify the player with the most made pull-up jump shots between 2018 and 2024.
# 28                                                                                   Which team had the most efficient offense in terms of points per shot attempt, excluding free throws, in the 2023 season?
# 29                                                                                                                          What was the shooting percentage of players on pull-up jumpers in the 2022 season?
# 30  Which player had the most significant improvement in regular-season scoring average from one season to the next between 2018 and 2024? Consider out of players who played at least 100 minutes per season.
# 31                                                                                                                  How many buzzer-beaters, at the end of the game, were made in the 2023 season and by whom?
# 32                                                                      What was the average regular-season turnover ratio for teams that made it to the playoffs versus those that didn't in the 2021 season?
# 33                                                                                         Which player had the highest usage rate in the 2020 season, and how did it correlate with their team's performance?
# 34                                                                                                         Compare the average playing time of starters versus bench players for each team in the 2022 season.
# 35        Which player scored the most clutch points in the 2023 season? Let’s define clutch points as points scored in the last 2 minutes of games where the teams’ scores are within 5 points of each other.
# 36                                                                                                           What was the relationship between player height and average rebounds per game in the 2021 season?
# 37                                              How did the shooting efficiency, in terms of Effective Field Goal percentage, of players differ between home and away regular season games in the 2022 season?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      answer  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The player who scored the most points in a single game between 2018 and 2024 is Liz Cambage, with a record of 53 points in one game.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        The team with the highest average points per game in the 2021 WNBA season was the Las Vegas Aces, averaging 89.25 points per game.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      In the 2023 WNBA season, there were 11 games that ended in overtime.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  In the 2020 WNBA season, Tiffany Mitchell had the highest free throw percentage among players who attempted at least 25 free throws. Her free throw percentage was 95.06%, making 77 out of 81 attempts.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              In the 2022 season, the Seattle Storm had the following win-loss records based on the type of games:\n\n- Regular Season (STD): 22 wins and 14 losses\n- Playoffs Round of 16 (RD16): 2 wins\n- Playoffs Semifinals (SEMI): 1 win and 3 losses\n\nOverall, they had a successful regular season and participated in multiple playoff rounds.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            In the 2019 WNBA season, including the postseason, the Washington Mystics had the longest winning streak, with a total of 32 consecutive wins.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Between 2018 and 2024, there were a total of 29 triple-doubles recorded in the WNBA. The player with the most triple-doubles during this period was Alyssa Thomas, who achieved 12 triple-doubles. Other notable players include Sabrina Ionescu with 4 triple-doubles, and Chelsea Gray, Candace Parker, and Courtney Vandersloot each with 2 triple-doubles.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          The team with the best defense in the 2024 WNBA season, measured by the lowest average opponent points per game, was the Sun, with an average of 71.08 opponent points per game.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The game with the highest combined score between 2018 and 2024 was between Team Stewart and Team Wilson, with a total score of 270 points. The game ID is 401558893.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The player who played the most minutes in the 2021 WNBA season was Skylar Diggins-Smith, with a total of 1440 minutes.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        The average attendance for WNBA games in the 2020 season was approximately 1,381 people per game.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   In the 2019 WNBA season, Courtney Vandersloot recorded the highest number of assists in a single game with 14 assists.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The Chicago Sky made it to the playoffs 4 times between 2018 and 2024.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          The average margin of victory for the Las Vegas Aces in the 2022 season was approximately 6.51 points per game.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           The player with the most steals in the 2023 WNBA season was Brittney Sykes, who recorded a total of 88 steals.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  The top 5 games with the highest attendance between 2018 and 2024 are as follows:\n\n1. Game ID 401620273 with an attendance of 20,333.\n2. Game ID 401620241 with an attendance of 19,103.\n3. Game ID 401018947 with an attendance of 19,076.\n4. Game ID 401620237 with an attendance of 18,343.\n5. Game ID 401391846 with an attendance of 18,100.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                      In the 2023 WNBA season, the average number of three-point shots made per game by each team is as follows:\n\n1. Team Wilson: 21.0\n2. Team Stewart: 21.0\n3. New York Liberty: 10.80\n4. Las Vegas Aces: 8.98\n5. Seattle Storm: 8.5\n6. Chicago Sky: 8.14\n7. Washington Mystics: 7.69\n8. Connecticut Sun: 7.49\n9. Dallas Wings: 6.87\n10. Minnesota Lynx: 6.79\n11. Phoenix Mercury: 6.78\n12. Indiana Fever: 6.73\n13. Atlanta Dream: 6.60\n14. Los Angeles Sparks: 6.5\n\nTeam Wilson and Team Stewart led the league with an average of 21 three-point shots made per game.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  The top 5 games with the most technical fouls called between 2018 and 2024 are as follows:\n\n1. Game ID 401507196 with 10 technical fouls.\n2. Game ID 401018917 with 9 technical fouls.\n3. Game ID 401320624 with 7 technical fouls.\n4. Game ID 401104994 with 6 technical fouls.\n5. Game ID 401018804 with 6 technical fouls.\n\nUnfortunately, without additional context or data linking game IDs to specific team matchups, I can't provide the teams involved in these games.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The top 3 rebounders in the 2021 WNBA season were:\n\n1. Brianna Turner with 411 rebounds.\n2. Brittney Griner with 379 rebounds.\n3. Jonquel Jones with 367 rebounds.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Brittney Griner recorded a total of 52 blocks in the 2023 WNBA season.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The average points per game of the top 3 scorers in each season from 2018 to 2024 are as follows:\n\n- **2018**: 6.48 points per game\n- **2019**: 6.25 points per game\n- **2020**: 6.96 points per game\n- **2021**: 6.76 points per game\n- **2022**: 6.71 points per game\n- **2023**: 6.68 points per game\n- **2024**: 7.04 points per game\n\nThis data shows a general consistency in scoring with a slight increase in 2024.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    In the 2021 WNBA season, the Phoenix Mercury had the highest average home game attendance, with an average of approximately 6,744 attendees per game.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The average plus-minus of players who played more than 30 minutes per game in the 2022 WNBA season was approximately 1.24.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 In the 2020 WNBA season, Arike Ogunbowale had the highest scoring average in games where her team lost, averaging 20.71 points per game.
# 24  Here are the shooting percentages for three-point shots versus two-point shots for the top 5 scorers in the 2023 WNBA season:\n\n1. **A'ja Wilson**\n   - **Three-Point Shooting**: 12 made out of 37 attempts (32.43%)\n   - **Two-Point Shooting**: 416 made out of 737 attempts (56.44%)\n\n2. **Breanna Stewart**\n   - **Three-Point Shooting**: 94 made out of 287 attempts (32.75%)\n   - **Two-Point Shooting**: 297 made out of 607 attempts (48.93%)\n\n3. **Jewell Loyd**\n   - **Three-Point Shooting**: 125 made out of 344 attempts (36.34%)\n   - **Two-Point Shooting**: 170 made out of 448 attempts (37.95%)\n\n4. **Arike Ogunbowale**\n   - **Three-Point Shooting**: 132 made out of 389 attempts (33.93%)\n   - **Two-Point Shooting**: 213 made out of 484 attempts (44.01%)\n\n5. **Kelsey Plum**\n   - **Three-Point Shooting**: 130 made out of 327 attempts (39.76%)\n   - **Two-Point Shooting**: 189 made out of 357 attempts (52.94%)\n\nThese statistics show a varied performance in shooting effici...
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               In the 2021 season, Courtney Vandersloot had the highest average assists in the last 3 minutes of games, averaging approximately 8.93 assists per game during these crucial final minutes.
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            In the 2019 WNBA season, the performance of players in terms of average points and assists per game varied by position rather than rookie or veteran status. Here's the breakdown:\n\n- Guards (G) averaged 8.33 points and 2.71 assists per game.\n- Forwards (F) averaged 7.98 points and 1.42 assists per game.\n- Centers (C) averaged 8.04 points and 1.01 assists per game.\n\nThis data suggests that guards were more involved in playmaking, while scoring was relatively even across all positions.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The player with the most made pull-up jump shots between 2018 and 2024 is not available in the current dataset. The query did not return any specific player details.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                In the 2023 season, the Las Vegas Aces had the most efficient offense in terms of points per shot attempt, excluding free throws, with an average of approximately 1.889 points per shot.
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  The database does not contain specific columns for pull-up field goals made or attempted, so I cannot directly calculate the shooting percentage for pull-up jumpers in the 2022 season. If you have any other questions or need information on different statistics, feel free to ask!
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The player who had the most significant improvement in regular-season scoring average from one season to the next between 2018 and 2024 was Diana Taurasi. She improved her scoring average by approximately 18.94 points per game from the 2019 season to the 2020 season.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       In the 2023 WNBA season, there were no recorded buzzer-beaters at the end of the game where the scoring play tied or won the game as time expired.
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 In the 2021 WNBA season, teams that did not make it to the playoffs had an average turnover ratio of approximately 13.14 turnovers per game. There is no data available for teams that made it to the playoffs, suggesting that all teams might have had turnovers above this average, or the data might be incomplete for those specific playoff games.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 In the 2020 WNBA season, Sabrina Ionescu had the highest usage rate with a calculated value of approximately 3168. Her team, the New York Liberty, had an average score of 71.86 points per game but allowed an average of 85.86 points per game to their opponents. This indicates that despite Ionescu's high involvement in the game, the team struggled defensively.
# 34  In the 2022 WNBA season, here are the average playing times for starters and bench players for each team:\n\n- **Atlanta Dream**: Starters averaged 26.65 minutes, Bench players averaged 15.20 minutes.\n- **Chicago Sky**: Starters averaged 28.07 minutes, Bench players averaged 14.03 minutes.\n- **Connecticut Sun**: Starters averaged 28.68 minutes, Bench players averaged 13.69 minutes.\n- **Dallas Wings**: Starters averaged 28.27 minutes, Bench players averaged 12.30 minutes.\n- **Indiana Fever**: Starters averaged 27.09 minutes, Bench players averaged 12.95 minutes.\n- **Las Vegas Aces**: Starters averaged 31.08 minutes, Bench players averaged 10.76 minutes.\n- **Los Angeles Sparks**: Starters averaged 28.08 minutes, Bench players averaged 14.50 minutes.\n- **Minnesota Lynx**: Starters averaged 26.54 minutes, Bench players averaged 14.87 minutes.\n- **New York Liberty**: Starters averaged 26.72 minutes, Bench players averaged 14.75 minutes.\n- **Phoenix Mercury**: Starters averaged ...
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        The player who scored the most clutch points in the 2023 WNBA season is Breanna Stewart, with a total of 6752 clutch points. Clutch points are defined as points scored in the last 2 minutes of games where the teams’ scores are within 5 points of each other.
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            It appears that the column `height_w_shoes` does not exist in the `wnba_player_box` table, and it is not available in the `wnba_player_info` table either. Unfortunately, without this specific column, I cannot directly analyze the relationship between player height and average rebounds per game for the 2021 season.\n\nIf you have any other questions or need information on different statistics, feel free to ask!
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Unfortunately, I am unable to retrieve the data regarding the Effective Field Goal percentage differences between home and away games for the 2022 WNBA season. There seems to be a persistent issue with accessing the specific data required. If you have any other questions or need information on a different topic, feel free to ask!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ground_truths
# ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Connecticut Sun (opponents held to 71.08 PPG)
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                           07/12/2022, Phoenix Mercury @ Minnesota Lynx (225 points combined)
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Skylar Diggins-Smith (1440 minutes)
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                          1.381 (note: all games had 0 attendance, but one game which had attendance of 203)
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Courtney Vandersloot (14 assists)
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     5 times
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 6.51 points
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Brittney Sykes (88 steals)
# 15                                                                                                                                                                                                        06/07/2024, Indiana Fever @ Washington Mystics (20,333 people)  05/25/2024, Indiana Fever @ Los Angeles Sparks (19,103 people) 08/05/2018, Phoenix Mercury @ Los Angeles Sparks (19,076 people) 05/23/2024, Indiana Fever @ Seattle Storm (18,343 people) 08/07/2022, Las Vegas Aces @ Seattle Storm (18,100 people)
# 16                                                                                                                                                                                                                                                          Atlanta Dream: 6.425 Chicago Sky: 8.25 Connecticut Sun: 7.175 Dallas Wings: 6.75 Indiana Fever: 6.725 Las Vegas Aces: 9.275 Los Angeles Sparks: 6.5 Minnesota Lynx: 6.75 New York Liberty: 11.1 Phoenix Mercury: 6.775 Seattle Storm: 8.5 Washington Mystics: 7.75
# 17                                                                                                                                                                                                                                                                                                                                                        06/20/2023, Atlanta Dream @ Dallas Wings (10 techs) 07/19/2018, New York Liberty @ Atlanta Dream (9 techs) 06/12/2021, Los Angeles Sparks @ Minnesota Lynx (7 techs)
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                   Brianna Turner (411 rebounds) Brittney Griner (379 rebounds) Jonquel Jones (367 rebounds)
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   52 blocks
# 20                                                                                                                                                     Average points per game increased over the 6 seasons for the top 3 scorers from 2018 to 2024.  Below are the top 3 scorers for 2018: Liz Cambage         22.65 PPG Breanna Stewart    22.07 PPG A'ja Wilson            20.59 PPG Below are the top 3 scorers for 2024: A'ja Wilson               28.64 PPG Arike Ogunbowale    26.18 PPG Kahleah Copper       23.54 PPG
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Phoenix Mercury (6,744 people)
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1.24
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Arike Ogunbowale (20.71 PPG)
# 24                                                                                                                                                                                                                                                                                                                                        A'ja Wilson 55.302 (FG) 32.43 (3P) Breanna Stewart 43.74 (FG) 32.75 (3P) Jewell Loyd 37.25 (FG)\t36.34 (3P) Arike Ogunbowale 39.52 (FG) 33.93 (3P) Kelsey Plum 46.64 (FG) 39.76 (3P)
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                       Candice Dupree & Kiana Williams (2 assists in the last 3 minutes of a game, per game)
# 26                                                                                                                                                                                                                                                                     Our dataset is not able to provide accurate data on who was a rookie or veteran in the 2019 season. Call-Out: This question is a good test for hallucinations and whether the model provides false data, or whether the model predicts this accurately.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Courtney Williams (488 made pull-up jumpers)
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Las Vegas Aces (1.08 points per shot attempt)
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      36.00%
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Myisha Hines-Allen (+ 14.67 PPG from 2019 to 2020)
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                   4 times (Breanna Stewart, Sophie Cunningham, Alanna Smith, Aliyah Boston)
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Playoff Teams: 1.02. Non-Playoff Teams: 0.91
# 33                                                                                                                                                                                                                                  Our dataset is not able to provide accurate data on league pace and team pace, so ultimately we won’t be able to determine usage rate. Call-Out: This question is a good test for hallucinations and whether the model provides false data, or whether the model predicts this accurately.
# 34   Team Name\t\t\tNon-Starter MPG\t\tStarter MPG\t Atlanta Dream\t\t\t14.57\t\t\t\t25.22 Chicago Sky\t\t\t11.65\t\t\t\t28.89 Connecticut Sun\t\t11.62\t\t\t\t28.49 Dallas Wings\t\t\t12.99\t\t\t\t26.00 Indiana Fever\t\t\t13.47\t\t\t\t25.65 Las Vegas Aces\t\t10.38\t\t\t\t28.56 Los Angeles Sparks\t\t15.85\t\t\t\t23.80 Minnesota Lynx\t\t13.42\t\t\t\t24.43 New York Liberty\t\t14.44\t\t\t\t25.92 Phoenix Mercury\t\t11.80\t\t\t\t27.82 Seattle Storm\t\t\t12.28\t\t\t\t28.59 Washington Mystics\t\t11.34\t\t\t\t27.85
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Arike Ogunbowale (37 clutch points)
# 36                                                                                                                                                                                                                                                                                                      Our dataset is not able to provide accurate data on player height. Call-Out: This question is a good test for hallucinations and whether the model provides false data, or whether the model predicts this accurately.
# 37                                                                                                                                                                                                                                                                                                                                                                                                                       In home games, players averaged an EFG% of 49.93%. In away games, players averaged an EFG% of 49.96%.

# %%
gpt4omini_text2sql = QAEngine("gpt-4o-mini", awsdb, 206, 1)
gpt4omini_text2sql_result = run_test(gpt4omini_text2sql, "text2sql")

# %%
gpt4omini_text2sql_result
# Out:
#                                                                                                                                                                                                       question  \
# 0                                                                                                                                  Which player scored the most points in a single game between 2018 and 2024?
# 1                                                                                                                                       Which team had the highest average points per game in the 2021 season?
# 2                                                                                                                                                     How many games ended in overtime during the 2023 season?
# 3                                                                                                              Which player had the highest free throw percentage in the 2020 season (min. 25 FT’s attempted)?
# 4                                                                                                                                        What was the win-loss record of the Seattle Storm in the 2022 season?
# 5                                                                                                                      Which team had the longest winning streak in the 2019 season (inclusive of postseason)?
# 6                                                                                                How many triple-doubles were recorded in the WNBA between 2018 and 2024, and who had the most triple-doubles?
# 7                                                                                                                                     Which team had the best defense in the 2024 season (by opponent points)?
# 8                                                                                                                            Identify the game with the highest combined score (both teams) from 2018 to 2024.
# 9                                                                                                                                                     Which player played the most minutes in the 2021 season?
# 10                                                                                                                                                What is the average attendance for games in the 2020 season?
# 11                                                                                                                     Which player had the highest number of assists in a single game during the 2019 season?
# 12                                                                                                                           How many times did the Chicago Sky make it to the playoffs between 2018 and 2024?
# 13                                                                                                                           What was the average margin of victory for the Las Vegas Aces in the 2022 season?
# 14                                                                                                                                                        Which player had the most steals in the 2023 season?
# 15                                                                                                                                 Identify the top 5 games with the highest attendance between 2018 and 2024.
# 16                                                                                                              What is the average number of three-point shots made per game by each team in the 2023 season?
# 17                                                                                                                                      Which games had the most technical fouls called between 2018 and 2024?
# 18                                                                                                                                                           Who were the top 3 rebounders in the 2021 season?
# 19                                                                                                                                  What was the total number of blocks by Brittney Griner in the 2023 season?
# 20                                                                                                              How did the average points per game of the top 3 scorers change each season from 2018 to 2024?
# 21                                                                                                                                 Which team had the highest average home game attendance in the 2021 season?
# 22                                                                                                     What was the average plus-minus of players who played more than 30 minutes per game in the 2022 season?
# 23                                                                                                         Which player had the highest scoring average in games where their team lost during the 2020 season?
# 24                                                                                      Compare the shooting percentages of three-point shots versus two-point shots for the top 5 scorers in the 2023 season.
# 25                                                                                                         Which player had the highest average assists in the last 3 minutes of games during the 2021 season?
# 26                                                                                  How did the performance of rookies compare to veterans in the 2019 season in terms of average points and assists per game?
# 27                                                                                                                            Identify the player with the most made pull-up jump shots between 2018 and 2024.
# 28                                                                                   Which team had the most efficient offense in terms of points per shot attempt, excluding free throws, in the 2023 season?
# 29                                                                                                                          What was the shooting percentage of players on pull-up jumpers in the 2022 season?
# 30  Which player had the most significant improvement in regular-season scoring average from one season to the next between 2018 and 2024? Consider out of players who played at least 100 minutes per season.
# 31                                                                                                                  How many buzzer-beaters, at the end of the game, were made in the 2023 season and by whom?
# 32                                                                      What was the average regular-season turnover ratio for teams that made it to the playoffs versus those that didn't in the 2021 season?
# 33                                                                                         Which player had the highest usage rate in the 2020 season, and how did it correlate with their team's performance?
# 34                                                                                                         Compare the average playing time of starters versus bench players for each team in the 2022 season.
# 35        Which player scored the most clutch points in the 2023 season? Let’s define clutch points as points scored in the last 2 minutes of games where the teams’ scores are within 5 points of each other.
# 36                                                                                                           What was the relationship between player height and average rebounds per game in the 2021 season?
# 37                                              How did the shooting efficiency, in terms of Effective Field Goal percentage, of players differ between home and away regular season games in the 2022 season?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      answer  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        The player who scored the most points in a single game between 2018 and 2024 is A'ja Wilson, with a remarkable total of 53 points.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The team with the highest average points per game in the 2021 season was the Las Vegas Aces, with an average of 89.25 points per game.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       During the 2023 season, there were 11 games that ended in overtime.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The player with the highest free throw percentage in the 2020 WNBA season, with a minimum of 25 free throws attempted, was **Tiffany Mitchell**, who achieved a free throw percentage of approximately **95.06%**. Following her were **Chelsea Gray** with about **93.88%** and **Crystal Dangerfield** with **92.19%**.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The Seattle Storm had a win-loss record of 25 wins and 17 losses in the 2022 season.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The team with the longest winning streak in the 2019 season was the Washington Mystics, with a total of 32 consecutive wins.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Between 2018 and 2024, a total of **252 triple-doubles** were recorded in the WNBA. The players who achieved this remarkable feat the most were **DeWanna Bonner** and **A'ja Wilson**, both with **252 triple-doubles** each. \n\nThis highlights the exceptional performance of these players in contributing to their teams across multiple statistical categories in various games.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The team with the best defense in the 2024 season, based on opponent points allowed, was the Connecticut Sun, with an average of approximately 71.08 points allowed per game.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The game with the highest combined score between both teams from 2018 to 2024 was a match in the 2023 season, which had a total score of 540 points. The specific game ID for this match is 401558893.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The player who played the most minutes in the 2021 season was Skylar Diggins-Smith, with a total of 1,440 minutes played.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The average attendance for games in the 2020 season was approximately 1,381 fans per game.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The player with the highest number of assists in a single game during the 2019 season was Courtney Vandersloot, who recorded 14 assists.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The Chicago Sky made it to the playoffs 4 times between 2018 and 2024.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The average margin of victory for the Las Vegas Aces in the 2022 season was approximately 6.36 points.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                The player with the most steals in the 2023 season was Brittney Sykes, who recorded a total of 88 steals.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The top 5 games with the highest attendance between 2018 and 2024 are:\n\n1. **Washington Mystics vs. Indiana Fever** - 20,333 attendees on June 7, 2024.\n2. **Los Angeles Sparks vs. Indiana Fever** - 19,103 attendees on May 24, 2024.\n3. **Los Angeles Sparks vs. Phoenix Mercury** - 19,076 attendees on August 5, 2018.\n4. **Seattle Storm vs. Indiana Fever** - 18,343 attendees on May 22, 2024.\n5. **Seattle Storm vs. Las Vegas Aces** - 18,100 attendees on August 7, 2022.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                    In the 2023 season, the average number of three-point shots made per game by each team was as follows:\n\n1. **New York Liberty**: 11.1\n2. **Las Vegas Aces**: 9.275\n3. **Seattle Storm**: 8.5\n4. **Chicago Sky**: 8.25\n5. **Washington Mystics**: 7.75\n\nOther teams included:\n- Connecticut Sun: 7.175\n- Phoenix Mercury: 6.775\n- Minnesota Lynx: 6.75\n- Dallas Wings: 6.75\n- Indiana Fever: 6.725\n- Los Angeles Sparks: 6.5\n- Atlanta Dream: 6.425\n\nThese statistics highlight the teams' proficiency in making three-point shots during the season.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The games with the most technical fouls called between 2018 and 2024 are as follows:\n\n1. **Dallas Wings vs. Atlanta Dream** - 10 technical fouls (Game ID: 401507196)\n2. **Atlanta Dream vs. New York Liberty** - 9 technical fouls (Game ID: 401018917)\n3. **Minnesota Lynx vs. Los Angeles Sparks** - 7 technical fouls (Game ID: 401320624)\n4. **New York Liberty vs. Dallas Wings** - 6 technical fouls (Game ID: 401018804)\n5. **Phoenix Mercury vs. Indiana Fever** - 6 technical fouls (Game ID: 401018960)
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The top 3 rebounders in the 2021 WNBA season were:\n\n1. **Brianna Turner** - 411 rebounds\n2. **Brittney Griner** - 379 rebounds\n3. **Jonquel Jones** - 367 rebounds
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Brittney Griner recorded a total of 52 blocks in the 2023 season.
# 20  The top 3 scorers in the WNBA from 2018 to 2024, based on average points per game, are:\n\n1. **A'ja Wilson**\n2. **Breanna Stewart**\n3. **DeWanna Bonner**\n\nHere’s how their average points per game changed each season:\n\n- **2018:**\n  - DeWanna Bonner: 18.31\n  - Breanna Stewart: 22.07\n  - A'ja Wilson: 20.59\n\n- **2019:**\n  - DeWanna Bonner: 17.19\n  - A'ja Wilson: 16.03\n\n- **2020:**\n  - Breanna Stewart: 21.08\n  - DeWanna Bonner: 18.69\n  - A'ja Wilson: 20.53\n\n- **2021:**\n  - DeWanna Bonner: 14.66\n  - A'ja Wilson: 17.45\n  - Breanna Stewart: 20.03\n\n- **2022:**\n  - A'ja Wilson: 19.44\n  - Breanna Stewart: 22.37\n  - DeWanna Bonner: 13.11\n\n- **2023:**\n  - A'ja Wilson: 22.65\n  - Breanna Stewart: 21.63\n  - DeWanna Bonner: 17.17\n\n- **2024:**\n  - Breanna Stewart: 18.92\n  - A'ja Wilson: 28.64\n  - DeWanna Bonner: 18.42\n\n### Summary of Trends:\n- A'ja Wilson had a significant increase in scoring in 2024, averaging 28.64 points per game.\n- Breanna Stewart cons...
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The team with the highest average home game attendance in the 2021 season was the **Phoenix Mercury**, with an average attendance of approximately **6,744** fans per game.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The average plus-minus of players who played more than 30 minutes per game in the 2022 season was approximately 1.24.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          The player with the highest scoring average in games where their team lost during the 2020 season was Arike Ogunbowale, with an average of approximately 20.71 points per game.
# 24  Here are the shooting percentages for three-point shots versus two-point shots for the top 5 scorers in the 2023 WNBA season:\n\n### Top 5 Scorers:\n1. **A'ja Wilson** - 1155 points\n2. **Breanna Stewart** - 1125 points\n3. **Jewell Loyd** - 970 points\n4. **Arike Ogunbowale** - 965 points\n5. **Kelsey Plum** - 938 points\n\n### Three-Point Shooting:\n- **Kelsey Plum**: 130 made, 327 attempted (3P% = 39.8%)\n- **Breanna Stewart**: 94 made, 287 attempted (3P% = 32.8%)\n- **Arike Ogunbowale**: 132 made, 389 attempted (3P% = 33.9%)\n- **Jewell Loyd**: 125 made, 344 attempted (3P% = 36.4%)\n\n### Two-Point Shooting:\n- **Arike Ogunbowale**: 345 made, 873 attempted (2P% = 39.5%)\n- **Jewell Loyd**: 295 made, 792 attempted (2P% = 37.2%)\n- **Kelsey Plum**: 319 made, 684 attempted (2P% = 46.7%)\n- **Breanna Stewart**: 391 made, 894 attempted (2P% = 43.7%)\n\n### Summary of Shooting Percentages:\n- **Kelsey Plum**: \n  - 3P%: 39.8%\n  - 2P%: 46.7%\n  \n- **Breanna Stewart**: \n  - 3P%: 32....
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The player with the highest average assists in the last 3 minutes of games during the 2021 season was **Courtney Vandersloot**, with an average of approximately **9.03 assists** per game.
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               In the 2019 season, the performance comparison between rookies and veterans in terms of average points and assists per game is as follows:\n\n- **Average Points per Game:**\n  - Rookies: **N/A** (no data available)\n  - Veterans: **8.15 points**\n\n- **Average Assists per Game:**\n  - Rookies: **N/A** (no data available)\n  - Veterans: **1.95 assists**\n\nIt appears that there were no recorded points or assists for rookies in the 2019 season based on the available data.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The player with the most made pull-up jump shots between 2018 and 2024 is associated with the athlete ID 2529205, having made a total of 418 pull-up jump shots. Unfortunately, I am unable to retrieve the player's name due to access restrictions in the database.\n\nIf you have any other questions or need further assistance, feel free to ask!
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     The team with the most efficient offense in terms of points per shot attempt (excluding free throws) in the 2023 season was the **Team Stewart**, with an average of approximately **1.23 points per shot attempt**.
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                In the 2022 season, there were no recorded pull-up jumpers made by players, resulting in a shooting percentage of 0% for pull-up jumpers.
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         The player with the most significant improvement in regular-season scoring average from one season to the next between 2018 and 2024 was **Alysha Clark**. She improved her scoring average from the previous season to the current season by **X points** (exact improvement value not provided in the result).
# 31  In the 2023 season, there were several scoring plays that occurred in the final moments of games, specifically within the last 5 seconds. Here are some notable plays that could be considered buzzer-beaters:\n\n1. **Courtney Vandersloot** made a two-point shot with an assist from Breanna Stewart in a game identified by ID `401578574`.\n2. **Kelsey Plum** made a 3-foot layup with an assist from Cayla George in the same game.\n3. **A'ja Wilson** made a 7-foot two-point shot in the same game.\n4. **Jonquel Jones** made a layup with an assist from Betnijah Laney in the same game.\n5. **Sabrina Ionescu** made a 23-foot three-point jumper with an assist from Courtney Vandersloot in a different game identified by ID `401578573`.\n\nThese plays indicate that there were multiple scoring plays in the closing seconds of games, but the exact number of official buzzer-beaters (where the shot is taken just before the game clock expires) is not clearly defined in the data. \n\nIf you need more spe...
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             In the 2021 season, the average regular-season turnover ratio for teams that made it to the playoffs was approximately **1.31**, while teams that did not make the playoffs had an average turnover ratio of about **0.86**. This indicates that playoff teams had a higher turnover ratio compared to non-playoff teams during that season.
# 33  It seems there was an issue retrieving the usage rate for players in the 2020 season due to a missing column in the database. However, I was able to gather information about team performance during that season.\n\n### Team Performance in the 2020 Season:\n- **Wins**:\n  - **Seattle Storm**: 24 wins\n  - **Las Vegas Aces**: 21 wins\n  - **Connecticut Sun**: 14 wins\n  - **Phoenix Mercury**: 14 wins\n  - **Los Angeles Sparks**: 15 wins\n  - **Chicago Sky**: 12 wins\n  - **Minnesota Lynx**: 15 wins\n  - **Dallas Wings**: 8 wins\n  - **Atlanta Dream**: 7 wins\n  - **New York Liberty**: 2 wins\n  - **Indiana Fever**: 6 wins\n  - **Washington Mystics**: 9 wins\n\n### Average Point Differential:\n- **Seattle Storm**: +12.36\n- **Las Vegas Aces**: +3.87\n- **Connecticut Sun**: +1.76\n- **Minnesota Lynx**: +2.00\n- **Phoenix Mercury**: +1.83\n- **Los Angeles Sparks**: +3.78\n- **Chicago Sky**: +1.96\n- **Dallas Wings**: -3.55\n- **Atlanta Dream**: -6.68\n- **New York Liberty**: -14.00\n- **...
# 34  In the 2022 season, the average playing time for starters and bench players across each team was as follows:\n\n### Average Minutes Played by Starters:\n- **Liberty**: 26.72 minutes\n- **Wings**: 28.27 minutes\n- **Mystics**: 27.54 minutes\n- **Mercury**: 31.78 minutes\n- **Aces**: 31.08 minutes\n- **Fever**: 27.09 minutes\n- **Lynx**: 26.54 minutes\n- **Sky**: 28.07 minutes\n- **Team Wilson**: 21.80 minutes\n- **Dream**: 26.65 minutes\n- **Sparks**: 28.08 minutes\n- **Storm**: 28.95 minutes\n- **Sun**: 28.68 minutes\n- **Team Stewart**: 18.60 minutes\n\n### Average Minutes Played by Bench Players:\n- **Sky**: 14.03 minutes\n- **Lynx**: 14.87 minutes\n- **Team Wilson**: 15.00 minutes\n- **Liberty**: 14.75 minutes\n- **Wings**: 12.30 minutes\n- **Mystics**: 13.81 minutes\n- **Mercury**: 11.03 minutes\n- **Aces**: 10.76 minutes\n- **Fever**: 12.95 minutes\n- **Dream**: 15.20 minutes\n- **Sparks**: 14.50 minutes\n- **Storm**: 13.12 minutes\n- **Sun**: 13.69 minutes\n- **Team Stewart**...
# 35                                                                                                                                                                                                                                                                                                                                                                                                       In the 2023 season, the player who scored the most clutch points (defined as points scored in the last 2 minutes of games where the teams' scores were within 5 points of each other) was identified, but the specific player information could not be retrieved due to a database access issue. \n\nHowever, the data indicates that a total of 1167 clutch points were scored by the player with athlete ID 0. Unfortunately, without access to the player information table, I cannot provide the name of the player associated with this ID. \n\nIf you have any other questions or need further assistance, feel free to ask!
# 36                                                                                                                                                                                                                                                                  To analyze the relationship between player height and average rebounds per game in the 2021 season, I gathered the average rebounds for players grouped by their height. Here are the results:\n\n1. **Height: 6'0"** - Average Rebounds: 11.12\n2. **Height: 5'9"** - Average Rebounds: 9.91\n3. **Height: 6'1"** - Average Rebounds: 9.63\n4. **Height: 5'10"** - Average Rebounds: 9.56\n5. **Height: 5'8"** - Average Rebounds: 9.29\n\nFrom this data, it appears that taller players tend to have a higher average of rebounds per game. The player with a height of 6'0" had the highest average rebounds, indicating a positive correlation between height and rebounding ability. \n\nIf you need more specific details or further analysis, feel free to ask!
# 37  In the 2022 WNBA season, the shooting efficiency in terms of Effective Field Goal percentage (eFG%) for players differed between home and away games as follows:\n\n### Home Games eFG%\n1. **Azura Stevens**: 49.36%\n2. **Allisha Gray**: 51.72%\n3. **Jasmine Dickey**: 30.00%\n4. **Charli Collier**: 42.86%\n5. **Jessica Shepard**: 47.14%\n6. **Natalie Achonwa**: 46.81%\n7. **Aerial Powers**: 43.93%\n8. **Elena Delle Donne**: 52.00%\n9. **Natasha Cloud**: 42.57%\n10. **Ariel Atkins**: 54.07%\n11. **Myisha Hines-Allen**: 47.92%\n12. **Tianna Hawkins**: 44.65%\n13. **Gabby Williams**: 46.26%\n14. **Jewell Loyd**: 43.27%\n15. **Briann January**: 40.44%\n16. **Candace Parker**: 57.06%\n17. **Allie Quigley**: 53.02%\n18. **Shey Peddy**: 53.59%\n19. **Diamond DeShields**: 39.33%\n20. **Erica Wheeler**: 37.07%\n21. **Kristy Wallace**: 46.51%\n22. **Aari McDonald**: 48.04%\n23. **DeWanna Bonner**: 48.69%\n24. **Odyssey Sims**: 34.21%\n25. **Natasha Howard**: 51.56%\n26. **Stefanie Dolson**: 54...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ground_truths
# ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Connecticut Sun (opponents held to 71.08 PPG)
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                           07/12/2022, Phoenix Mercury @ Minnesota Lynx (225 points combined)
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Skylar Diggins-Smith (1440 minutes)
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                          1.381 (note: all games had 0 attendance, but one game which had attendance of 203)
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Courtney Vandersloot (14 assists)
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     5 times
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 6.51 points
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Brittney Sykes (88 steals)
# 15                                                                                                                                                                                                        06/07/2024, Indiana Fever @ Washington Mystics (20,333 people)  05/25/2024, Indiana Fever @ Los Angeles Sparks (19,103 people) 08/05/2018, Phoenix Mercury @ Los Angeles Sparks (19,076 people) 05/23/2024, Indiana Fever @ Seattle Storm (18,343 people) 08/07/2022, Las Vegas Aces @ Seattle Storm (18,100 people)
# 16                                                                                                                                                                                                                                                          Atlanta Dream: 6.425 Chicago Sky: 8.25 Connecticut Sun: 7.175 Dallas Wings: 6.75 Indiana Fever: 6.725 Las Vegas Aces: 9.275 Los Angeles Sparks: 6.5 Minnesota Lynx: 6.75 New York Liberty: 11.1 Phoenix Mercury: 6.775 Seattle Storm: 8.5 Washington Mystics: 7.75
# 17                                                                                                                                                                                                                                                                                                                                                        06/20/2023, Atlanta Dream @ Dallas Wings (10 techs) 07/19/2018, New York Liberty @ Atlanta Dream (9 techs) 06/12/2021, Los Angeles Sparks @ Minnesota Lynx (7 techs)
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                   Brianna Turner (411 rebounds) Brittney Griner (379 rebounds) Jonquel Jones (367 rebounds)
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   52 blocks
# 20                                                                                                                                                     Average points per game increased over the 6 seasons for the top 3 scorers from 2018 to 2024.  Below are the top 3 scorers for 2018: Liz Cambage         22.65 PPG Breanna Stewart    22.07 PPG A'ja Wilson            20.59 PPG Below are the top 3 scorers for 2024: A'ja Wilson               28.64 PPG Arike Ogunbowale    26.18 PPG Kahleah Copper       23.54 PPG
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Phoenix Mercury (6,744 people)
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1.24
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Arike Ogunbowale (20.71 PPG)
# 24                                                                                                                                                                                                                                                                                                                                        A'ja Wilson 55.302 (FG) 32.43 (3P) Breanna Stewart 43.74 (FG) 32.75 (3P) Jewell Loyd 37.25 (FG)\t36.34 (3P) Arike Ogunbowale 39.52 (FG) 33.93 (3P) Kelsey Plum 46.64 (FG) 39.76 (3P)
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                       Candice Dupree & Kiana Williams (2 assists in the last 3 minutes of a game, per game)
# 26                                                                                                                                                                                                                                                                     Our dataset is not able to provide accurate data on who was a rookie or veteran in the 2019 season. Call-Out: This question is a good test for hallucinations and whether the model provides false data, or whether the model predicts this accurately.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Courtney Williams (488 made pull-up jumpers)
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Las Vegas Aces (1.08 points per shot attempt)
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      36.00%
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Myisha Hines-Allen (+ 14.67 PPG from 2019 to 2020)
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                   4 times (Breanna Stewart, Sophie Cunningham, Alanna Smith, Aliyah Boston)
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Playoff Teams: 1.02. Non-Playoff Teams: 0.91
# 33                                                                                                                                                                                                                                  Our dataset is not able to provide accurate data on league pace and team pace, so ultimately we won’t be able to determine usage rate. Call-Out: This question is a good test for hallucinations and whether the model provides false data, or whether the model predicts this accurately.
# 34   Team Name\t\t\tNon-Starter MPG\t\tStarter MPG\t Atlanta Dream\t\t\t14.57\t\t\t\t25.22 Chicago Sky\t\t\t11.65\t\t\t\t28.89 Connecticut Sun\t\t11.62\t\t\t\t28.49 Dallas Wings\t\t\t12.99\t\t\t\t26.00 Indiana Fever\t\t\t13.47\t\t\t\t25.65 Las Vegas Aces\t\t10.38\t\t\t\t28.56 Los Angeles Sparks\t\t15.85\t\t\t\t23.80 Minnesota Lynx\t\t13.42\t\t\t\t24.43 New York Liberty\t\t14.44\t\t\t\t25.92 Phoenix Mercury\t\t11.80\t\t\t\t27.82 Seattle Storm\t\t\t12.28\t\t\t\t28.59 Washington Mystics\t\t11.34\t\t\t\t27.85
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Arike Ogunbowale (37 clutch points)
# 36                                                                                                                                                                                                                                                                                                      Our dataset is not able to provide accurate data on player height. Call-Out: This question is a good test for hallucinations and whether the model provides false data, or whether the model predicts this accurately.
# 37                                                                                                                                                                                                                                                                                                                                                                                                                       In home games, players averaged an EFG% of 49.93%. In away games, players averaged an EFG% of 49.96%.
